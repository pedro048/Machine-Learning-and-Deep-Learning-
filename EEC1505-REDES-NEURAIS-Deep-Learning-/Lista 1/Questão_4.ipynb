# %%
import numpy as np
from mpl_toolkits import mplot3d
from matplotlib import pyplot as plt
from matplotlib import cm

# %%
def f(x,y):
  return 2*x**2-2*x*y+4*y**2+5

def g(x,y):
  return x+y

# %%
x = np.outer(np.linspace(-5.0, 5.0,100), np.ones(100))
y = np.outer(np.ones(100), np.linspace(-5.0,5.0,100))
z = f(x,y)

# %%
ax = plt.axes(projection = '3d')
ax.view_init(50,30)
ax.plot_surface(x,y,z, cmap=cm.coolwarm)
ax.set_xlabel('eixo x')
ax.set_ylabel('eixo y')
ax.set_zlabel('eixo z')
# Out:
# Text(0.5, 0, 'eixo z')

# %%
def f1(x):
  return 2*x**2-2*x*x+4*x**2+5

# %%
x = np.linspace(-2,2)  
plt.plot(x, f1(x))  
plt.grid()  
plt.show()

# %%
x = np.outer(np.linspace(-5.0, 5.0,100), np.ones(100))
y = np.outer(np.ones(100), np.linspace(-5.0,5.0,100))
z = g(x,y)

# %%
ax = plt.axes(projection = '3d')
ax.view_init(50,30)
ax.plot_surface(x,y,z, cmap=cm.coolwarm)
ax.set_xlabel('eixo x')
ax.set_ylabel('eixo y')
ax.set_zlabel('eixo z')
# Out:
# Text(0.5, 0, 'eixo z')

# %%
def g1(x):
  return x+x

# %%
x = np.linspace(-2,2)  
plt.plot(x, g1(x))  
plt.grid()  
plt.show()
